# %% [markdown]
# ## Naive RAG over KG triples (line-wise)\n
# \n
# This notebook indexes **each JSONL line** from `Bundesliga23_24_test_triples_linearized.jsonl` as a separate document in Chroma, using Ollama embeddings (`nomic-embed-text`).\n
# \n
# Pros: simplest possible baseline.\n
# Cons: each triple is tiny, so retrieval can miss supporting facts that belong together.\n

# %%
# Install dependencies (run once)\n
# !pip install -q chromadb requests

# %%
from pathlib import Path
import json
from typing import List, Dict, Any, Iterable, Optional

import requests
import chromadb
from chromadb.config import Settings

project_root = Path('.').resolve()
jsonl_path = project_root / 'Bundesliga23_24_test_triples_linearized.jsonl'
print('Project root:', project_root)
print('JSONL exists:', jsonl_path.exists(), jsonl_path)
# Out:
# Project root: C:\Users\dyury\Desktop\Master Thesis
# JSONL exists: True C:\Users\dyury\Desktop\Master Thesis\Bundesliga23_24_test_triples_linearized.jsonl

# %%
def iter_jsonl_texts(path: Path, max_lines: Optional[int] = 50000) -> Iterable[str]:
    """Yield the 'text' field from each JSONL line.

    max_lines is just for experimentation; set to None for full file.
    """
    n = 0
    with open(path, 'r', encoding='utf-8') as f:
        for line in f:
            if max_lines is not None and n >= max_lines:
                break
            line = line.strip()
            if not line:
                continue
            obj = json.loads(line)
            text = obj.get('text')
            if isinstance(text, str) and text:
                yield text
                n += 1


# Preview
preview = list(iter_jsonl_texts(jsonl_path, max_lines=5))
for i, t in enumerate(preview):
    print(i, t)
# Out:
# 0 event/62ead0ab-e3ec-46fa-ab33-7b9d0473a344 x 48.6
# 1 match/3895052 events event/ce261d4b-9c4d-4414-a519-e95dea8a0fa3
# 2 event/7d2cc416-583e-4918-a35e-429b12a4aa83 y_end 70.0
# 3 event/d7f33026-3427-45b8-b838-3801ffb99a25 receiver_time 01:19:16.477
# 4 event/a8aa1263-3b1e-4640-89e7-434c09d27f53 event_period second_half

# %%
class OllamaEmbeddingFunction:
    """Minimal embedding function wrapper for Chroma using Ollama."""

    def __init__(self, model: str = 'nomic-embed-text', base_url: str = 'http://localhost:11434'):
        self.model = model
        self.url = f'{base_url}/api/embeddings'

    def _embed_texts(self, texts: List[str]) -> List[List[float]]:
        vectors: List[List[float]] = []
        for text in texts:
            resp = requests.post(self.url, json={'model': self.model, 'prompt': text})
            resp.raise_for_status()
            vectors.append(resp.json()['embedding'])
        return vectors

    def embed_documents(self, input: List[str]) -> List[List[float]]:
        return self._embed_texts(input)

    def embed_query(self, input):
        if isinstance(input, str):
            return self._embed_texts([input])[0]
        return self._embed_texts(input)

    def __call__(self, input: List[str]) -> List[List[float]]:
        return self.embed_documents(input)

    def name(self) -> str:
        return f'ollama-{self.model}'

# %%
# Build documents (each line is one doc)
MAX_LINES = 50000  # set None for full file, but start small

docs: List[Dict[str, Any]] = []
for idx, text in enumerate(iter_jsonl_texts(jsonl_path, max_lines=MAX_LINES)):
    docs.append({'id': f'line::{idx}', 'text': text})

print('Docs:', len(docs))
print('Example:', docs[0])
# Out:
# Docs: 46725
# Example: {'id': 'line::0', 'text': 'event/62ead0ab-e3ec-46fa-ab33-7b9d0473a344 x 48.6'}

# %%
# Create Chroma collection (batched add)
chroma_client = chromadb.Client(Settings(anonymized_telemetry=False))
embedding_function = OllamaEmbeddingFunction()

COLLECTION_NAME = 'kg_triples_linewise'
RESET_COLLECTION = True  # set False to keep existing index
BATCH_SIZE = 5000  # must be <= Chroma max batch size (yours: 5461)

if RESET_COLLECTION:
    try:
        chroma_client.delete_collection(COLLECTION_NAME)
        print('Deleted existing collection:', COLLECTION_NAME)
    except Exception:
        pass

collection = chroma_client.get_or_create_collection(
    name=COLLECTION_NAME,
    embedding_function=embedding_function,
)

ids_all = [d['id'] for d in docs]
docs_all = [d['text'] for d in docs]

for start in range(0, len(docs_all), BATCH_SIZE):
    end = min(start + BATCH_SIZE, len(docs_all))
    collection.add(
        ids=ids_all[start:end],
        documents=docs_all[start:end],
    )
    print(f'Indexed {end}/{len(docs_all)}')

print('Indexed total:', collection.count())
# Out:
# ---------------------------------------------------------------------------
# InternalError                             Traceback (most recent call last)
# Cell In[6], line 10
#       3 embedding_function = OllamaEmbeddingFunction()
#       5 collection = chroma_client.get_or_create_collection(
#       6     name='kg_triples_linewise',
#       7     embedding_function=embedding_function,
#       8 )
# ---> 10 collection.add(
#      11     ids=[d['id'] for d in docs],
#      12     documents=[d['text'] for d in docs],
#      13 )
#      15 print('Indexed:', collection.count())
#
# File c:\Users\dyury\anaconda3\Lib\site-packages\chromadb\api\models\Collection.py:116, in Collection.add(self, ids, embeddings, metadatas, documents, images, uris)
#      90 """Add records to the collection.
#      91
#      92 Args:
#    (...)    104     ValueError: If an ID already exists.
#     105 """
#     107 add_request = self._validate_and_prepare_add_request(
#     108     ids=ids,
#     109     embeddings=embeddings,
#    (...)    113     uris=uris,
#     114 )
# --> 116 self._client._add(
#     117     collection_id=self.id,
#     118     ids=add_request["ids"],
#     119     embeddings=add_request["embeddings"],
#     120     metadatas=add_request["metadatas"],
#     121     documents=add_request["documents"],
#     122     uris=add_request["uris"],
#     123     tenant=self.tenant,
#     124     database=self.database,
#     125 )
#
# File c:\Users\dyury\anaconda3\Lib\site-packages\chromadb\api\rust.py:454, in RustBindingsAPI._add(self, ids, collection_id, embeddings, metadatas, documents, uris, tenant, database)
#     432 @override
#     433 def _add(
#     434     self,
#    (...)    442     database: str = DEFAULT_DATABASE,
#     443 ) -> bool:
#     444     self.product_telemetry_client.capture(
#     445         CollectionAddEvent(
#     446             collection_uuid=str(collection_id),
#    (...)    451         )
#     452     )
# --> 454     return self.bindings.add(
#     455         ids,
#     456         str(collection_id),
#     457         embeddings,
#     458         metadatas,
#     459         documents,
#     460         uris,
#     461         tenant,
#     462         database,
#     463     )
#
# InternalError: ValueError: Batch size of 46725 is greater than max batch size of 5461

# %%
def call_llama_chat(
    prompt: str,
    model: str = 'llama3.1:8b',
    base_url: str = 'http://localhost:11434',
) -> str:
    url = f'{base_url}/api/chat'
    resp = requests.post(
        url,
        json={
            'model': model,
            'messages': [{'role': 'user', 'content': prompt}],
            'stream': False,
        },
    )
    resp.raise_for_status()
    return resp.json()['message']['content']


def rag_answer(question: str, top_k: int = 16) -> str:
    results = collection.query(query_texts=[question], n_results=top_k)
    context = '\n'.join(results['documents'][0])

    prompt = f"""
You answer questions using ONLY the facts in the context.
If the answer is not present, say you don't know.

Context (KG triples):
{context}

Question: {question}
Answer:
""".strip()

    return call_llama_chat(prompt)

# %%
# Example query
question = 'Which team_id is Bayern Munich associated with?'
print(rag_answer(question, top_k=20))
